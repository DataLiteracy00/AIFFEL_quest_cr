# %%
import pandas as pd
import os

from sklearn.decomposition import PCA

# %%
salary1_data_path = os.getenv("HOME") + "/programming/AI/AIFFEL/AIFFEL_quest_cr/Python/data/salary_1.csv"
salary2_data_path = os.getenv("HOME") + "/programming/AI/AIFFEL/AIFFEL_quest_cr/Python/data/salary_2.csv"
cpi_path = os.getenv("HOME") + "/programming/AI/AIFFEL/AIFFEL_quest_cr/Python/data/cpi.csv"
job_path = os.getenv("HOME") + "/programming/AI/AIFFEL/AIFFEL_quest_cr/Python/data/job.csv"

# %%
salary1_data = pd.read_csv(salary1_data_path)
salary2_data = pd.read_csv(salary2_data_path)
cpi_data = pd.read_csv(cpi_path)
job_data = pd.read_csv(job_path)

# %%
salary_df = pd.concat([salary1_data, salary2_data])
salary_df.reset_index(drop = True, inplace = True)

# %%
cpi_data['Country'] = cpi_data['Country'].replace({'United States': 'USA', 'United Kingdom': 'UK'}) 
salary_df = salary_df.merge(cpi_data, on = 'Country', how = 'left')
salary_df.drop(['Reference', 'Previous', 'Units', 'Frequency'], axis = 1, inplace = True)
salary_df.rename({'Last': 'CPI'}, axis = 1, inplace = True)

# %%
salary_df = salary_df.merge(job_data, on = 'Job Title', how = 'left')
salary_df.drop('Job Title', axis=1, inplace=True)
salary_df = pd.get_dummies(salary_df, columns=['Gender', 'Country', 'Race', 'Jobs'], drop_first=True)
salary_df['CPI'] = pd.to_numeric(salary_df['CPI'])
salary_df = salary_df.dropna()

# %%
pca = PCA()

# %%
pca.fit(salary_df)
# Out:
# PCA()

# %%
pca_df = pd.DataFrame(pca.transform(salary_df))
pca_df
# Out:
#                 0           1          2   ...        76        77            78
# 0    -25308.106768  -35.890383   0.408278  ...  0.001799  0.000121  5.345677e-07
# 1    -50308.112436  138.836052  -0.342510  ...  0.000955 -0.001219  9.788885e-07
# 2     34691.894114   -7.377061   8.543806  ... -0.000850  0.027913 -1.426540e-05
# 3    -55308.111189  138.672590   9.216368  ... -0.000453 -0.001372  8.849291e-07
# 4     84691.890263  142.922966  10.344474  ...  0.415430  0.073060  1.557951e-04
# ...            ...         ...        ...  ...       ...       ...           ...
# 6675  84691.895288  -32.557472   7.658740  ... -0.001290 -0.001780 -1.356431e-07
# 6676 -65308.106654  -33.809876   4.838542  ... -0.000645  0.000031  7.693564e-07
# 6677 -60308.105739  -68.957655   2.999019  ...  0.000899  0.000454  8.659291e-08
# 6678  24691.895999  -66.384687  10.114267  ... -0.001036 -0.000511  2.584409e-07
# 6679 -80308.108025  -10.860710   0.828700  ...  0.000016 -0.000468 -2.206214e-07
#
# [6680 rows x 79 columns]

# %%
pca = PCA(2)

# %%
pd.DataFrame(pca.fit_transform(salary_df), columns=['PC1', 'PC2'])
# Out:
#                PC1         PC2
# 0    -25308.106768  -35.890383
# 1    -50308.112436  138.836052
# 2     34691.894114   -7.377061
# 3    -55308.111189  138.672590
# 4     84691.890263  142.922966
# ...            ...         ...
# 6675  84691.895288  -32.557472
# 6676 -65308.106654  -33.809876
# 6677 -60308.105739  -68.957655
# 6678  24691.895999  -66.384687
# 6679 -80308.108025  -10.860710
#
# [6680 rows x 2 columns]

# %%
(pca.explained_variance_ratio_).sum()
# Out:
# np.float64(0.99999998450227)

# %%
salary_df.corr()
# Out:
#                                Age  ...  Jobs_Web Developer
# Age                       1.000000  ...           -0.068303
# Education Level           0.596173  ...           -0.062120
# Years of Experience       0.923760  ...           -0.101497
# Salary                    0.728332  ...           -0.147767
# Senior                    0.333717  ...           -0.057418
# ...                            ...  ...                 ...
# Jobs_Technical Writer    -0.010652  ...           -0.001717
# Jobs_Training Specialist  0.013417  ...           -0.002428
# Jobs_UX                   0.013377  ...           -0.004207
# Jobs_Web Designer        -0.007430  ...           -0.001717
# Jobs_Web Developer       -0.068303  ...            1.000000
#
# [79 rows x 79 columns]
